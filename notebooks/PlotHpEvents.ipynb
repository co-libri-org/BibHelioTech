# %%
import os
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

print(os.getcwd())

import import_ipynb
from CatDfLib import cat2df, plotcat
# Out:
# /home/richard/01DEV/bht2/notebooks
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[25], line 9
#       6 print(os.getcwd())
#       8 import import_ipynb
# ----> 9 from CatDfLib import cat2df, plotcat
#
# ImportError: cannot import name 'plotcat' from 'CatDfLib' (CatDfLib.ipynb)

# %%
    


filepath = os.path.join(os.getcwd(), '..', 'resources-tests', '105194angeo282332010_bibheliotech_V1.txt')

_df =  cat2df(filepath)
plotcat(_df)
