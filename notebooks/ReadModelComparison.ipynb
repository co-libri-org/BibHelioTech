# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

import import_ipynb
from CatDfLib import cat2df, plotcat, lines2df


cmp_dir = "cmp_dir/"
cmp_file = os.path.join(cmp_dir, "BHT_model_comparison.xlsx")



my_df = pd.read_excel(cmp_file, header=0)

my_df.columns=["paper", "link", "comment", "bht_paper", "bht_cat", "haiku_cat", "6", "7", "sonnet_cat", "exe_haiku", "exe_sonnet"]

for i in range(5):
    bht_cat = my_df.bht_cat[i]
    bht_list = bht_cat.split("\n")
    haiku_cat = my_df.haiku_cat[i]
    haiku_list = haiku_cat.split("\n")
    sonnet_cat = my_df.sonnet_cat[i]
    sonnet_list = sonnet_cat.split("\n")
    
    fig, ax = plt.subplots(3, figsize=(10,10), sharex=False)
    plt.subplots_adjust( top=0.9, bottom=0.1)
    plt.tight_layout() 

    for ax_idx, _cat in enumerate([bht_list, haiku_list, sonnet_list]):
        print("-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+")
        try:
            _df = lines2df(_cat)
            plotcat(_df, title=paper, ax=ax[ax_idx])
        except IndexError:
            continue
# Out:
# -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# -+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+-+
# ...
